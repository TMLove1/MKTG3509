# %% [markdown]
# **Rationale** Perhaps the most important medium of communicating data-driven insights is through the construction of effective graphs. This assignment is designed for you to practice making some common types of graphs.
#
# [Datasets](https://drive.google.com/open?id=1-oR65kkGk7TIzBtRGXVWhkeU1q7yIc-x&authuser=tul67796%40temple.edu&usp=drive_fs) required
#
# 1. [Rent the Runway item fit](https://drive.google.com/open?id=15UtPTWFea2YfU51SRrZJDyM4aI0YXVFU&authuser=tul67796%40temple.edu&usp=drive_fs)
# 1. [Orange Telecom customer churn](https://drive.google.com/open?id=15eDf_6pamH9GLA1PNMdOlF4YSYHu_zc8&authuser=tul67796%40temple.edu&usp=drive_fs)

# %% [markdown]
# # 1. (5 points) Bar Plot - Rent the runway dataset
#
# For categories with at least 100 observations, plot the proportion of reviews that indicated that the item fits using a bar plot.
#
# Answer these questions (see detailed prompt at end of section):
#
# 1. Which categories fit the best? Which categories fit the worst? based off the fiirst 20 rows, gowns fit best and dresses fit worst
# 1. Does this bar plot confirm or reject your prior expectations? Explain. N/A
# 1. How can you mitigate the fit issues? By offering tailor option on sight
#
#
# **Follow each of the steps below**

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# import the libraries you need: (pandas, matplotlib)

import os, pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# specify the folder in your Google MyDrive containing the datasets for this assignment
fpath = 'drive/MyDrive/Customer Data Analysis/'
os.listdir(fpath)
# Out:
# ['MyNotes Mod1.ipynb',
#  'A1 Treasure Love_Part1.ipynb',
#  'A1_Part2.ipynb',
#  'MyNotes_Mod2.ipynb',
#  'A2 Programming Fundamentals.ipynb',
#  'stores A data-set.csv',
#  'stores data-set.csv',
#  'stores B data-set.csv',
#  'stores C data-set.csv',
#  'sales data-set.csv',
#  '9-8_notes2.ipynb',
#  'Colab Notebooks',
#  'quebec_yelp_reviews.csv',
#  'quebec_biz.csv',
#  'Quebec_dataset.csv',
#  '9-8_notes.ipynb',
#  'A3.ipynb',
#  'Copy of InClass_Module_3.ipynb',
#  '9 22_Notes.ipynb',
#  'telecom_churn.csv',
#  'renttherunway_final_data.json',
#  'A4.ipynb',
#  'Notes_Sept15.ipynb',
#  'Copy of A4 F2021 - Visualization.ipynb']

# %%
# read in file use read_json(fpath + 'rentherunway_final_data.json', lines = True)
# call the dataframe: rent

rent = pd.read_json(fpath + 'renttherunway_final_data.json', lines = True)
rent.head(20)
# Out:
#       fit  user_id bust size  item_id  ... height  size    age         review_date
# 0     fit   420272       34d  2260466  ...  5' 8"    14   28.0      April 20, 2016
# 1     fit   273551       34b   153475  ...  5' 6"    12   36.0       June 18, 2013
# 2     fit   360448       NaN  1063761  ...  5' 4"     4  116.0   December 14, 2015
# 3     fit   909926       34c   126335  ...  5' 5"     8   34.0   February 12, 2014
# 4     fit   151944       34b   616682  ...  5' 9"    12   27.0  September 26, 2016
# 5     fit   734848       32b   364092  ...  5' 8"     8   45.0      April 30, 2016
# 6     fit   336066       34c   568429  ...  5' 3"     4   27.0    December 7, 2017
# 7     fit    86661      34d+   130259  ...  5' 3"     8   65.0     January 1, 2013
# 8     fit   166228       36d  1729232  ...  5' 6"    21   27.0       June 27, 2016
# 9     fit   154309       32b  1729232  ...  5' 3"     1   33.0    October 17, 2016
# 10  small   185966       34b  1077123  ...  5' 3"    12   33.0     January 2, 2018
# 11  large   533900       34b   130259  ...  5' 6"     8   30.0     January 7, 2013
# 12    fit    87660       36a  1295171  ...  5' 6"     8   26.0       July 28, 2016
# 13  large   391778       36d   143094  ...  5' 2"    20   29.0     October 4, 2014
# 14    fit   721308       34b   123793  ...  5' 5"     2   32.0        May 29, 2014
# 15    fit   829124       34c  2595752  ...  5' 7"    20   30.0        May 16, 2016
# 16    fit   499943       34c   909221  ...  5' 8"    20   35.0      March 28, 2017
# 17    fit   339899       34d  1622747  ...  5' 5"    12   26.0   November 13, 2017
# 18    fit   649288       34b   172027  ...  5' 3"     8   28.0        July 3, 2017
# 19  small    16800       34c  1229740  ...  5' 6"    21   33.0   November 16, 2017
#
# [20 rows x 15 columns]

# %%
# preview the first 5 rows the dataset to get a sense of its contents

rent.head()
# Out:
#    fit  user_id bust size  item_id  ... height  size    age         review_date
# 0  fit   420272       34d  2260466  ...  5' 8"    14   28.0      April 20, 2016
# 1  fit   273551       34b   153475  ...  5' 6"    12   36.0       June 18, 2013
# 2  fit   360448       NaN  1063761  ...  5' 4"     4  116.0   December 14, 2015
# 3  fit   909926       34c   126335  ...  5' 5"     8   34.0   February 12, 2014
# 4  fit   151944       34b   616682  ...  5' 9"    12   27.0  September 26, 2016
#
# [5 rows x 15 columns]

# %% [markdown]
# **Double click to edit**
#
# Fill in the blanks
#
# * In the dataframe `rent`, one row represents the data for one user
#
# To construct a dataframe that has 1 row = 1 category and summarize the number of rows per category:
#
# * Which variable should you groupby? category
# * Which variable can you summarize? user_id
# * Which summary function should you use? count

# %%
# execute the groupby to construct the desired dataframe (remember to add .reset_index() to the end of the groupby statement)
# call the resulting dataframe (assign to this variable): count100

count100 = rent.groupby('category')['user_id'].count().reset_index()
count100.head()
# Out:
#    category  user_id
# 0  ballgown       16
# 1    blazer      782
# 2    blouse      651
# 3   blouson       14
# 4    bomber      128

# %%
# rename the columns to 'category' and 'obs'

count100.rename(columns = {'user_id':'obs'}, inplace = True)

# %% [markdown]
# **Double click to edit**\
# Fill in the blanks
#
# To merge `cat100` and `rent`, we should use count100 as the left dataframe and category as the right dataframe.
#
# We should merge on the variable category
#
# We will use an inner merge.

# %%
# merge count100 with the rent, reuse the variable rent by replacing it with the result of the merge

rent = rent.merge(count100, how = 'left', on = 'category')

# %%
# preview rent dataframe to show that there's a new column: "obs"

rent.head()
# Out:
#    fit  user_id bust size  item_id  ... size    age         review_date    obs
# 0  fit   420272       34d  2260466  ...   14   28.0      April 20, 2016   3070
# 1  fit   273551       34b   153475  ...   12   36.0       June 18, 2013  44381
# 2  fit   360448       NaN  1063761  ...    4  116.0   December 14, 2015  19316
# 3  fit   909926       34c   126335  ...    8   34.0   February 12, 2014  92884
# 4  fit   151944       34b   616682  ...   12   27.0  September 26, 2016  44381
#
# [5 rows x 16 columns]

# %%
# what are the unique values in fit column? select the fit column and use the .unique() method

rent['fit'].unique()
# Out:
# array(['fit', 'small', 'large'], dtype=object)

# %%
# create a column in rent called 'fit1'


# first initialize the fit1 column where all observations in the column are 0's 
# modify the generic syntax df['column name'] = 0

rent['fit1'] = 0

# select the subset of fit1 column where fit column has the value "fit"
## e.g. select rows where fit column has the value 'fit' and the column 'fit1'
## set these rows of the fit1 column = 1 (modify the syntax df.loc[conditions, 'column name'] = 1)

rent.loc[rent.fit=='fit', 'fit1'] = 1

# %%
# sample 20 random rows of the rent dataframe, make sure the fit1 column corresponds
# to the correct rows as indicated by the fit column
# (run the code several times if you don't see any rows that indicate item did not fit (fit1 is 0))

rent100.sample(20)
# Out:
#           fit  user_id bust size  item_id  ...   age        review_date    obs fit1
# 49191   small    64174       34d  1940985  ...  62.0      June 25, 2017  92884    0
# 100887    fit   973108       34b   134015  ...  26.0  November 18, 2013  44381    1
# 80231     fit   146951   34ddd/e   919589  ...  27.0  December 18, 2017  44381    1
# 182589    fit   508035       34b   245079  ...  49.0      July 30, 2016  92884    1
# 36718     fit   765831       36b  1718885  ...  32.0     August 1, 2017  92884    1
# 95146   small   926055       36b  1000254  ...  22.0    October 4, 2017  92884    0
# 143576  large   239158       32c  2678083  ...  28.0     March 14, 2017   4931    0
# 166493  large   400120       34b   127865  ...  40.0   January 30, 2014  44381    0
# 6591    small   585053      36d+   524341  ...  38.0        May 2, 2017  44381    0
# 162053    fit   528784       34b  1210233  ...  29.0     March 24, 2017  44381    1
# 80581     fit   461275       34d  1730006  ...  28.0     March 27, 2015  92884    1
# 137328    fit   984943       34a   649983  ...  31.0      June 15, 2016  92884    1
# 155891    fit   274229       34b  1786364  ...  35.0      July 12, 2016  19316    1
# 150940    fit    61951   40ddd/e  1573248  ...  50.0   November 6, 2017  92884    1
# 110862    fit   132854      32d+   142179  ...  23.0     March 17, 2014  44381    1
# 6055      fit   889292       34a  2473413  ...  34.0    August 14, 2016   4931    1
# 15163     fit   162507       34c  1034372  ...  28.0        May 2, 2016  92884    1
# 98517     fit   954532       32d  2688785  ...  32.0  December 12, 2017   5184    1
# 31010     fit   210158       34c   131533  ...  44.0     April 13, 2016  44381    1
# 127006    fit   420374       34d  1484383  ...  30.0     April 17, 2016  92884    1
#
# [20 rows x 17 columns]

# %%
# Create a new dataframe, rent100, that is the subset of rows of rent that come from categories with at least 100 observations
# Modify the generic syntax newdf = olddf.loc[condition]

rent100 = rent.loc[(rent.obs>=100)]

# %% [markdown]
# **Double click to edit**
#
# To construct a dataframe that has 1 row = 1 category and summarize the proportion of rental reviews that indicate the item from that category fits
#
# * Which variable should you groupby? category
# * Which variable can you summarize? fit1
# * Which summary function should you use? groupby

# %%
# execute the groupby
# (remember to add .reset_index() to the end of the groupby statement)
# call the resulting dataframe (assign to this variable): fit100 

fit100 = rent100.groupby('category')['fit1'].mean().reset_index()

# %%
# display the fit100 dataframe, make sure it contains the expected information
# e.g. category and proportion of fit

fit100
# Out:
#       category      fit1
# 0       blazer  0.760870
# 1       blouse  0.743472
# 2       bomber  0.734375
# 3     cardigan  0.659751
# 4         coat  0.595918
# 5     culottes  0.691489
# 6         down  0.698276
# 7        dress  0.716668
# 8        frock  0.687805
# 9         gown  0.792614
# 10      jacket  0.699251
# 11    jumpsuit  0.745756
# 12    leggings  0.785714
# 13        maxi  0.756608
# 14        mini  0.742433
# 15        pant  0.710280
# 16       pants  0.623223
# 17       print  0.854369
# 18      romper  0.732248
# 19      sheath  0.753210
# 20       shift  0.683504
# 21       shirt  0.631769
# 22  shirtdress  0.695473
# 23       skirt  0.686479
# 24        suit  0.869919
# 25     sweater  0.711923
# 26  sweatshirt  0.696000
# 27        tank  0.690608
# 28         top  0.731697
# 29       tunic  0.641975
# 30        vest  0.586331

# %%
# sort this fit100 dataframe from smallest to largest proportion
# be sure to specify the inplace = True option to alter the dataframe
# we need this step to make the resulting bar plot ordered from shortest 
# to tallest bar
# modify the generic syntax df.sort_values(by = 'sort column name', inplace = True)

fit100.sort_values('fit1', inplace = True)

# %%
# display the resulting dataframe again to make sure it is properly sorted

fit100
# Out:
#       category      fit1
# 30        vest  0.586331
# 4         coat  0.595918
# 16       pants  0.623223
# 21       shirt  0.631769
# 29       tunic  0.641975
# 3     cardigan  0.659751
# 20       shift  0.683504
# 23       skirt  0.686479
# 8        frock  0.687805
# 27        tank  0.690608
# 5     culottes  0.691489
# 22  shirtdress  0.695473
# 26  sweatshirt  0.696000
# 6         down  0.698276
# 10      jacket  0.699251
# 15        pant  0.710280
# 25     sweater  0.711923
# 7        dress  0.716668
# 28         top  0.731697
# 18      romper  0.732248
# 2       bomber  0.734375
# 14        mini  0.742433
# 1       blouse  0.743472
# 11    jumpsuit  0.745756
# 19      sheath  0.753210
# 13        maxi  0.756608
# 0       blazer  0.760870
# 12    leggings  0.785714
# 9         gown  0.792614
# 17       print  0.854369
# 24        suit  0.869919

# %%
# construct the bar plot
# make the bar plot easy to read by:
# adjust the figure size
# x-axis labels degrees
# other appearance parameters

# MAKE SURE TO LABEL YOUR AXES
 
plt.figure(figsize = (35,8))
plt.bar(fit100.category, 
            fit100.fit1, 
            alpha = .5)
plt.xlabel('category')
plt.ylabel('fit1')
plt.title('Bar Plot')
# Out:
# Text(0.5, 1.0, 'Bar Plot')

# %% [markdown]
# **Double Click to Edit**
# 1. The category that fit best is suit.
#     1. The category that fit worst is vest.
# 1. (Explain why the plot makes (or doesn't make) sense. Write at least 4 sentences.) The plot makes sense. It depicts which clothes fit the best for which customers. You can use this chart for deciding what to buy at this store, and based on the data table, you can see which body types fit which clothes the best.
# 1. Two strategies that can mitigate the fit issues are:
#     1. My first strategy would be to tailor the clothes to fit better
#     1. My next would be to call the factory to report discrepancies

# %% [markdown]
# # 2. (5 points) Scatter plot - Orange Telecom
#
# Create 2 plots:
#
# First, construct a scatter plot that visualizes the relationship between the number of calls made and the cost per call paid.
#
# Second, construct a scatter plot that visualizes total minutes used and average rate paid per minute, use color to indicate churned customers.
#
# Note that customer **churn** is the marketing term for a customer who has defected / ended the business relationship (cancelled their contract).
#
# Be sure to:
# 1. **adjust the sizes / colors / transparency** of the points to be visually appealing.
# 1. Label your axes
#
# Questions:
# 1. Describe the relationship between number of calls and cost per call.
#     1. What might explain this relationship? Longer calls cost more money
# 1. Describe any differences in the usage patterns among customers who have churned vs. those who have not?
#     1. What might cause the(se) difference(s)?
#
# **Follow the detailed prompts below**

# %%
# read in your dataset using read_csv(fpath + 'telecom_churn.csv')
# call the dataframe orange

orange = pd.read_csv(fpath + 'telecom_churn.csv')

# %%
# preview the first 5 rows to get a sense of this data

orange.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %% [markdown]
# **Double click to edit**
# Fill in the blank
# 1. Each row represents the data for one caller.

# %%
# create 3 new columns:
# 'Total_Minutes': sum of total day, eve, night, and international minutes
# 'Total_Charges' sum of total day, eve, night, and international charges
# 'Total_Calls' sum of total day, eve, night, and international calls

orange['Total_Minutes'] = orange['Total day minutes'] + orange['Total eve minutes'] + orange['Total night minutes'] + orange['Total intl minutes']
orange['Total_Charges'] = orange['Total day charge'] + orange['Total eve charge'] + orange['Total night charge'] + orange['Total intl charge']
orange['Total_Calls'] = orange['Total day calls'] + orange['Total eve calls'] + orange['Total night calls'] + orange['Total intl calls']

orange.head()
# Out:
#   State  Account length  Area code  ... Total_Minutes Total_Charges  Total_Calls
# 0    KS             128        415  ...         717.2         75.56          303
# 1    OH             107        415  ...         625.2         59.24          332
# 2    NJ             137        415  ...         539.4         62.29          333
# 3    OH              84        408  ...         564.8         66.80          255
# 4    OK              75        415  ...         512.0         52.09          359
#
# [5 rows x 23 columns]

# %%
# create 2 additional columns
# 'Avg_Rate': the average charge per minute (use columns created above to help you make the new column)
# 'Cost_Per_Call': the average charge per call (use columns created above to help you make the new column)

orange['Avg_Rate'] = orange['Total_Charges']/orange['Total_Calls']
orange['Cost_Per_Call'] = orange['Total_Charges']/ orange['Total_Minutes']

# %%
# Create the first scatter plot
# Use the x-axis for number of calls
# Use the y-axis for the cost per call
# Label both axes
# play with plotting parameters (size, alpha, figure size, etc.) to make the plot more appealing
# make the figure size 10 x 8

plt.figure(figsize = (10,8))
plt.scatter(orange.Total_Calls, 
            orange.Cost_Per_Call, 
            alpha = .5,  
            cmap = 'RdYlGn_r')
plt.xlabel('Total Calls')
plt.ylabel('Cost per Call')
# Out:
# Text(0, 0.5, 'Cost per Call')

# %% [markdown]
# **Double Click to Edit**
#
# Answers
#
# 1. (Describe the relationship between calls and cost per call)
#     1. (Reason 1 for why this relatinship may exist)
#     1. (Reason 2 for why this relationship may exist)

# %%
## Create the second plot
# this figure requires making 2 plots on the same figure: one for churned, one for not 
# (e.g. select the rows that are churned (or not) and the appropriate column for the x and y values that go into the scatter plot function)
# Recall, you can select a subset of a particular column using the syntax: df.loc[conditions, 'column name']
# note the condition to select churned (not) customer should be orange.Churn == True (orange.Churn == False)

# make the churned group color red
# make the not churned group color green

# adjust the transparency, dot size, etc. to make the figure appealing
# CREATE A LEGEND, make sure the legend is legible
# make the figure size 10 x 8

# %% [markdown]
# **Double Click to Edit**
#
# Answers
#
# 1. Customers who have more than 4 customer service calls are more likely to churn
# 1. They could churn because they didn't get the service they thought they deserved, or never got their problem finished
